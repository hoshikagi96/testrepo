# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0, 3*np.pi, 500)
plt.plot(x, np.sin(x**2))

# %%
tokyo_temps = [15.1, 15.4, 15.2, 20.1, 18.2, 16.3]
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(tokyo_temps)
